# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://trc19485:53kfgv1n1%2Br49sth@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# DB2/LINUXX8664

# %%
# %%sql
# select CR.CASE_NUMBER, CR.PRIMARY_TYPE, CD.COMMUNITY_AREA_NAME
# from CHICAGO_CRIME_DATA CR inner join CENSUS_DATA CD
# on CR.COMMUNITY_AREA_NUMBER = CD.COMMUNITY_AREA_NUMBER
# where CR.COMMUNITY_AREA_NUMBER = 18;
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('JA560123', 'CRIMINAL DAMAGE', 'Montclaire'),
#  ('JA107722', 'OTHER OFFENSE', 'Montclaire')]

# %%
# %%sql
# select TABNAME, COLNAME from syscat.columns where tabname = 'CENSUS_DATA';
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('CENSUS_DATA', 'COMMUNITY_AREA_NAME'),
#  ('CENSUS_DATA', 'COMMUNITY_AREA_NUMBER'),
#  ('CENSUS_DATA', 'HARDSHIP_INDEX'),
#  ('CENSUS_DATA', 'PERCENT_AGED_16__UNEMPLOYED'),
#  ('CENSUS_DATA', 'PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA'),
#  ('CENSUS_DATA', 'PERCENT_AGED_UNDER_18_OR_OVER_64'),
#  ('CENSUS_DATA', 'PERCENT_HOUSEHOLDS_BELOW_POVERTY'),
#  ('CENSUS_DATA', 'PERCENT_OF_HOUSING_CROWDED'),
#  ('CENSUS_DATA', 'PER_CAPITA_INCOME')]

# %%
# %%sql
# select TABNAME, COLNAME from syscat.columns where tabname = 'CHICAGO_CRIME_DATA';
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('CHICAGO_CRIME_DATA', 'ARREST'),
#  ('CHICAGO_CRIME_DATA', 'BEAT'),
#  ('CHICAGO_CRIME_DATA', 'BLOCK'),
#  ('CHICAGO_CRIME_DATA', 'CASE_NUMBER'),
#  ('CHICAGO_CRIME_DATA', 'COMMUNITY_AREA_NUMBER'),
#  ('CHICAGO_CRIME_DATA', 'DATE'),
#  ('CHICAGO_CRIME_DATA', 'DESCRIPTION'),
#  ('CHICAGO_CRIME_DATA', 'DISTRICT'),
#  ('CHICAGO_CRIME_DATA', 'DOMESTIC'),
#  ('CHICAGO_CRIME_DATA', 'FBICODE'),
#  ('CHICAGO_CRIME_DATA', 'ID'),
#  ('CHICAGO_CRIME_DATA', 'IUCR'),
#  ('CHICAGO_CRIME_DATA', 'LATITUDE'),
#  ('CHICAGO_CRIME_DATA', 'LOCATION'),
#  ('CHICAGO_CRIME_DATA', 'LOCATION_DESCRIPTION'),
#  ('CHICAGO_CRIME_DATA', 'LONGITUDE'),
#  ('CHICAGO_CRIME_DATA', 'PRIMARY_TYPE'),
#  ('CHICAGO_CRIME_DATA', 'WARD'),
#  ('CHICAGO_CRIME_DATA', 'X_COORDINATE'),
#  ('CHICAGO_CRIME_DATA', 'YEAR'),
#  ('CHICAGO_CRIME_DATA', 'Y_COORDINATE')]

# %%
# %%sql
# select TABNAME, COLNAME from syscat.columns where tabname = 'CHICAGO_PUBLIC_SCHOOLS';
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('CHICAGO_PUBLIC_SCHOOLS', '10th Grade PLAN (2009)'),
#  ('CHICAGO_PUBLIC_SCHOOLS', '10th Grade PLAN (2010)'),
#  ('CHICAGO_PUBLIC_SCHOOLS', '11th Grade Average ACT (2011)'),
#  ('CHICAGO_PUBLIC_SCHOOLS', '9th Grade EXPLORE (2009)'),
#  ('CHICAGO_PUBLIC_SCHOOLS', '9th Grade EXPLORE (2010)'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'AVERAGE_STUDENT_ATTENDANCE'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'Adequate_Yearly_Progress_Made_'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'Average_Teacher_Attendance'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'COLLEGE_ENROLLMENT'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'COMMUNITY_AREA_NAME'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'COMMUNITY_AREA_NUMBER'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'CPS_Performance_Policy_Level'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'CPS_Performance_Policy_Status'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'City'),
#  ('CHICAGO_PUBLIC_SCHOOLS', 'Collaborative_Name'),
# ...

# %%
# %%sql
# select CR.CASE_NUMBER, CR.PRIMARY_TYPE, CD.COMMUNITY_AREA_NAME
# from CHICAGO_CRIME_DATA CR inner join CENSUS_DATA CD
# on CR.COMMUNITY_AREA_NUMBER = CD.COMMUNITY_AREA_NUMBER
# where CR.LOCATION_DESCRIPTION like '%SCHOOL%'
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('HK577020', 'NARCOTICS', 'Rogers Park'),
#  ('HL725506', 'BATTERY', 'Lincoln Square'),
#  ('HH639427', 'BATTERY', 'Austin'),
#  ('HS200939', 'CRIMINAL DAMAGE', 'Austin'),
#  ('HT315369', 'ASSAULT', 'East Garfield Park'),
#  ('HP716225', 'BATTERY', 'Douglas'),
#  ('HL353697', 'BATTERY', 'South Shore'),
#  ('HS305355', 'NARCOTICS', 'Brighton Park'),
#  ('JA460432', 'BATTERY', 'Ashburn'),
#  ('HR585012', 'CRIMINAL TRESPASS', 'Ashburn')]

# %%
# %%sql
# select CR.CASE_NUMBER, CR.PRIMARY_TYPE, CD.COMMUNITY_AREA_NAME, CD.COMMUNITY_AREA_NUMBER
# from CHICAGO_CRIME_DATA CR inner join CENSUS_DATA CD
# on CR.COMMUNITY_AREA_NUMBER = CD.COMMUNITY_AREA_NUMBER
# where CD.COMMUNITY_AREA_NAME in ('Oakland','Edgewater','Armour Square', 'CHICAGO')
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('HV537004', 'THEFT', 'Edgewater', 77),
#  ('HM392612', 'THEFT', 'Edgewater', 77)]

# %%
# %sql select distinct(COMMUNITY_AREA_NAME), COMMUNITY_AREA_NUMBER from CENSUS_DATA order by COMMUNITY_AREA_NAME
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Albany Park', 14),
#  ('Archer Heights', 57),
#  ('Armour Square', 34),
#  ('Ashburn', 70),
#  ('Auburn Gresham', 71),
#  ('Austin', 25),
#  ('Avalon Park', 45),
#  ('Avondale', 21),
#  ('Belmont Cragin', 19),
#  ('Beverly', 72),
#  ('Bridgeport', 60),
#  ('Brighton Park', 58),
#  ('Burnside', 47),
#  ('CHICAGO', None),
#  ('Calumet Heights', 48),
#  ('Chatham', 44),
#  ('Chicago Lawn', 66),
#  ('Clearing', 64),
#  ('Douglas', 35),
#  ('Dunning', 17),
#  ('East Garfield Park', 27),
#  ('East Side', 52),
#  ('Edgewater', 77),
#  ('Edison Park', 9),
#  ('Englewood', 68),
#  ('Forest Glen', 12),
#  ('Fuller Park', 37),
#  ('Gage Park', 63),
#  ('Garfield Ridge', 56),
#  ('Grand Boulevard', 38),
#  ('Greater Grand Crossing', 69),
#  ('Hegewisch', 55),
#  ('Hermosa', 20),
#  ('Humboldt park', 23),
#  ('Hyde Park', 41),
#  ('Irving Park', 16),
#  ('Jefferson Park', 11),
# ...
