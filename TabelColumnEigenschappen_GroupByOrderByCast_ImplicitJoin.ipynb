# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://trc19485:53kfgv1n1%2Br49sth@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# DB2/LINUXX8664

# %%
# %sql select TABSCHEMA, TABNAME, CREATE_TIME from syscat.tables where TABSCHEMA = 'TRC19485'
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('TRC19485', 'TEST', datetime.datetime(2021, 4, 20, 14, 39, 26, 240258)),
#  ('TRC19485', 'PETSALE', datetime.datetime(2021, 4, 20, 14, 43, 26, 467548)),
#  ('TRC19485', 'EMPLOYEES', datetime.datetime(2021, 4, 20, 14, 58, 49, 680242)),
#  ('TRC19485', 'JOB_HISTORY', datetime.datetime(2021, 4, 20, 14, 58, 49, 837334)),
#  ('TRC19485', 'JOBS', datetime.datetime(2021, 4, 20, 14, 58, 49, 962623)),
#  ('TRC19485', 'DEPARTMENTS', datetime.datetime(2021, 4, 20, 14, 58, 50, 89161)),
#  ('TRC19485', 'LOCATIONS', datetime.datetime(2021, 4, 20, 14, 58, 50, 217751)),
#  ('TRC19485', 'CHICAGO_SOCIOECONOMIC_DATA', datetime.datetime(2021, 5, 3, 10, 8, 48, 631539)),
#  ('TRC19485', 'INSTRUCTOR', datetime.datetime(2021, 5, 3, 13, 29, 30, 924170)),
#  ('TRC19485', 'INTERNATIONAL_STUDENT_TEST_SCORES2', datetime.datetime(2021, 5, 3, 14, 41, 41, 51244)),
# ...

# %%
# %sql select * from SYSCAT.TABLES where TABNAME= 'ChicagoPublicSchools'
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# []

# %%
# %sql SELECT COLNAME,TYPENAME, LENGTH from SYSCAT.COLUMNS where tabname='CHICAGOPUBLICSCHOOLS'
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('School_ID', 'INTEGER', 4),
#  ('NAME_OF_SCHOOL', 'VARCHAR', 65),
#  ('Elementary, Middle, or High School', 'VARCHAR', 2),
#  ('Street_Address', 'VARCHAR', 29),
#  ('City', 'VARCHAR', 7),
#  ('State', 'VARCHAR', 2),
#  ('ZIP_Code', 'INTEGER', 4),
#  ('Phone_Number', 'VARCHAR', 14),
#  ('Link', 'VARCHAR', 78),
#  ('Network_Manager', 'VARCHAR', 40),
#  ('Collaborative_Name', 'VARCHAR', 34),
#  ('Adequate_Yearly_Progress_Made_', 'VARCHAR', 3),
#  ('Track_Schedule', 'VARCHAR', 12),
#  ('CPS_Performance_Policy_Status', 'VARCHAR', 16),
#  ('CPS_Performance_Policy_Level', 'VARCHAR', 15),
#  ('HEALTHY_SCHOOL_CERTIFIED', 'VARCHAR', 3),
#  ('Safety_Icon', 'VARCHAR', 11),
#  ('SAFETY_SCORE', 'SMALLINT', 2),
#  ('Family_Involvement_Icon', 'VARCHAR', 11),
#  ('Family_Involvement_Score', 'VARCHAR', 3),
#  ('Environment_Icon', 'VARCHAR', 11),
#  ('Environment_Score', 'SMALLINT', 2),
# ...

# %%
# %sql Select * from ChicagoPublicSchools limit 1
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# ...

# %%
# %sql Select count(*) from ChicagoPublicSchools where 'Elementary, Middle, or High School' = 'es'
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('0'),)]

# %%
# %sql Select MAX(SAFETY_SCORE) AS MAX_SAFETY_SCORE from ChicagoPublicSchools
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(99,)]

# %%
# %sql Select NAME_OF_SCHOOL from ChicagoPublicSchools where SAFETY_SCORE = 99
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Abraham Lincoln Elementary School',),
#  ('Alexander Graham Bell Elementary School',),
#  ('Annie Keller Elementary Gifted Magnet School',),
#  ('Augustus H Burley Elementary School',),
#  ('Edgar Allan Poe Elementary Classical School',),
#  ('Edgebrook Elementary School',),
#  ('Ellen Mitchell Elementary School',),
#  ('James E McDade Elementary Classical School',),
#  ('James G Blaine Elementary School',),
#  ('LaSalle Elementary Language Academy',),
#  ('Mary E Courtenay Elementary Language Arts Center',),
#  ('Northside College Preparatory High School',),
#  ('Northside Learning Center High School',),
#  ('Norwood Park Elementary School',),
#  ('Oriole Park Elementary School',),
#  ('Sauganash Elementary School',),
#  ('Stephen Decatur Classical Elementary School',),
#  ('Talman Elementary School',),
#  ('Wildwood Elementary School',)]

# %%
# %sql Select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE from ChicagoPublicSchools order by AVERAGE_STUDENT_ATTENDANCE desc nulls last limit 10
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('John Charles Haines Elementary School', '98.40%'),
#  ('James Ward Elementary School', '97.80%'),
#  ('Edgar Allan Poe Elementary Classical School', '97.60%'),
#  ('Orozco Fine Arts & Sciences Elementary School', '97.60%'),
#  ('Rachel Carson Elementary School', '97.60%'),
#  ('Annie Keller Elementary Gifted Magnet School', '97.50%'),
#  ('Andrew Jackson Elementary Language Academy', '97.40%'),
#  ('Lenart Elementary Regional Gifted Center', '97.40%'),
#  ('Disney II Magnet School', '97.30%'),
#  ('John H Vanderpoel Elementary Magnet School', '97.20%')]

# %%
# %sql Select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE from ChicagoPublicSchools order by AVERAGE_STUDENT_ATTENDANCE fetch first 5 rows only
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%')]

# %%
# %sql Select NAME_OF_SCHOOL, REPLACE(AVERAGE_STUDENT_ATTENDANCE,'%','') from ChicagoPublicSchools order by AVERAGE_STUDENT_ATTENDANCE fetch first 5 rows only
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90'),
#  ('Dyett High School', '62.50'),
#  ('Wendell Phillips Academy High School', '63.00'),
#  ('Orr Academy High School', '66.30')]

# %%
# %sql Select NAME_OF_SCHOOL, AVERAGE_STUDENT_ATTENDANCE \
from ChicagoPublicSchools \
where CAST(REPLACE(AVERAGE_STUDENT_ATTENDANCE,'%','') as DOUBLE) < 70.00 \
order by Average_Student_Attendance
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Richard T Crane Technical Preparatory High School', '57.90%'),
#  ('Barbara Vick Early Childhood & Family Center', '60.90%'),
#  ('Dyett High School', '62.50%'),
#  ('Wendell Phillips Academy High School', '63.00%'),
#  ('Orr Academy High School', '66.30%'),
#  ('Manley Career Academy High School', '66.80%'),
#  ('Chicago Vocational Career Academy High School', '68.80%'),
#  ('Roberto Clemente Community Academy High School', '69.60%')]

# %%
# %sql select Community_Area_name, sum(COLLEGE_ENROLLMENT) as Total_Enrollment from ChicagoPublicSchools group by Community_Area_Name
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('ALBANY PARK', 6864),
#  ('ARCHER HEIGHTS', 4823),
#  ('ARMOUR SQUARE', 1458),
#  ('ASHBURN', 6483),
#  ('AUBURN GRESHAM', 4175),
#  ('AUSTIN', 10933),
#  ('AVALON PARK', 1522),
#  ('AVONDALE', 3640),
#  ('BELMONT CRAGIN', 14386),
#  ('BEVERLY', 1636),
#  ('BRIDGEPORT', 3167),
#  ('BRIGHTON PARK', 9647),
#  ('BURNSIDE', 549),
#  ('CALUMET HEIGHTS', 1568),
#  ('CHATHAM', 5042),
#  ('CHICAGO LAWN', 7086),
#  ('CLEARING', 2085),
#  ('DOUGLAS', 4670),
#  ('DUNNING', 4568),
#  ('EAST GARFIELD PARK', 5337),
#  ('EAST SIDE', 5305),
#  ('EDGEWATER', 4600),
#  ('EDISON PARK', 910),
#  ('ENGLEWOOD', 6832),
#  ('FOREST GLEN', 1431),
#  ('FULLER PARK', 531),
#  ('GAGE PARK', 9915),
#  ('GARFIELD RIDGE', 4552),
#  ('GRAND BOULEVARD', 2809),
#  ('GREATER GRAND CROSSING', 4051),
#  ('HEGEWISCH', 963),
#  ('HERMOSA', 3975),
#  ('HUMBOLDT PARK', 8620),
#  ('HYDE PARK', 1930),
# ...

# %%
# %sql select Community_Area_Name, sum(COLLEGE_ENROLLMENT) as Total_Enrollment from ChicagoPublicSchools \
group by Community_Area_Name \
order by Total_enrollment asc\
fetch first 5 rows only
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('OAKLAND', 140),
#  ('FULLER PARK', 531),
#  ('BURNSIDE', 549),
#  ('OHARE', 786),
#  ('LOOP', 871)]

# %%
# %sql select NAME_OF_SCHOOL, SAFETY_SCORE from ChicagoPublicSchools \
order by SAFETY_SCORE \
limit 5
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Edmond Burke Elementary School', 1),
#  ("Luke O'Toole Elementary School", 5),
#  ('George W Tilton Elementary School', 6),
#  ('Foster Park Elementary School', 11),
#  ('Emil G Hirsch Metropolitan High School', 13)]

# %%
# %%sql
# select hardship_index from chicago_socioeconomic_data1 CD, ChicagoPublicSchools S
# where CD.ca=S.community_area_number
# and college_enrollment = 4368
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(6.0,)]

# %%
# %%sql
# select ca, community_area_name, hardship_index from chicago_socioeconomic_data1 CD
# where ca in (select community_area_number from ChicagoPublicSchools S
# order by college_enrollment asc
# limit 1)
# Out:
#  * ibm_db_sa://trc19485:***@dashdb-txn-sbox-yp-lon02-13.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(28.0, 'Near West Side', 15.0)]
